# %%
a = [1,2,3]

a.upper
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 L = [1,2,3]
# ----> 3 L.upper
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
a = 'pakistan'
a.append('a')

# %% [markdown]
# ab yaha pr note krne wali baay hy k python har cheez ko object bula rha even yaha pr koi bhi xheez ho list, tuple, dictionary.
#
# In python there is a famous line that:
#
# **Everythin in Python is an object**
#
# Is sy hum ko ye samjh ata hy k **object** and **OOP(object oriented programming)** me ku6 connection hy jo k hum samjhy gy.

# %% [markdown]
# ## **Why wee need OOP**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The main power of OOP is that it allows a programmer to create its own data types.
#
# is k ilawa bhi or bohat sare featueres hoty hy jaise
# - polymorphism
# - inheritence
# - encapsulation
# - abstraction
#
# all the moderen aplication are OOP based.

# %% [markdown]
# ## Principles of OOP

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = [1,2,3]

print(type(a))
# Out:
# <class 'list'>

# %%
a.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# ab tak hum ny jitni bhi data type study ki hy chahy wo list, array, touple,
#
# actually all these are class.
#
# yaha note krny wali baat ye class kis ko bulana hy or object kis ko bulana hy
#
# ab agr is example me dekhy to list jo hy wo aik class hy jo hum ny variable bnaya hy wo object hy

# %% [markdown]
# # Class
#
# Class basically a bluprint
# a set of rules k us k object jo hy wo behave kasie kre ga
#
# Example:
# 1. Mobles are class and samsung is object

# %%
a = [1,2,3]

# %%
a.

# %% [markdown]
# Class me do cheezy hoti hy k is me likha kia jata hy
# 1. Data or property
# 2. Function or behavior
#
# Example
# car aik class hy
# data: color
# function kia hy average speed k koi bhi input dy gy to ouput mily gi

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **Object**
# Object is an instance of the class
#
# Ali is an instance or object of class 10th
#
# ![image.png](attachment:image.png)

# %%
# syntax to create an object
# objectname = classname()

# %%
# now you can say that pehly to hum ny is trah bnaya tha
a = [1, 2, 3]

# %%
# to hum us ko aise bhi bna skty hy

l = list([1,2,3,3])

l
# Out:
# [1, 2, 3, 3]

# %%
a = str()

# %% [markdown]
# abhi tak jo kia hy wo revise ke lety hy
#
# hum ny dekha k OOP kia hota hy
# its a very different way of writing code
# is me object and classes hoty hy
# is me ap apni data types bna skty ho
#
# basically real world application bnany me bohat help krta hy
#
# **Classes** are set of rules object jin ko follow krty hy

# %% [markdown]
# ## Writing ATM Machine code

# %%
# Class name should be in pascal case like HelloWorld

class Atm:

    # constructor-- jab bhi ap koi variable bnao gy to bas itna yaad rakho k constructor k andar bnao gy
    def __init__(self):
        # Rule no 1. variable ko construtor k andar bnaye gy
        # Rule no 2. jo variable ka name hy us k agy sellf. lgaye gy
        self.pin = ''
        self.balance = 0

# %%
# abhi hum ny sirf class bnaye hy or ab hum is class ka object bnaye gy
# object bnany ka syntax kia tha
# onjectname = classname()

obj = Atm()

# %% [markdown]
# Python me 2 type ki classes hoti hy
# 1. Builtin Classes like list, tuple etc.
# 2. User defiened class jo programmer apny hisab sy bnata hy

# %%
type(obj)
# Out:
# __main__.Atm

# %%
obj.

# %%
class Atm:
    # constructor--> constructor hai to aik function hi hy lakin ye aik special qisam ka function hy= has a super power.
    # bcz is k andar jo code hy u sko execute krny k lia us function call krny ki zrurat nhi hoti. wo khud hi execute ho jata hy.
    # jab ap is class ka object bnao gy to us k andar ka jo code hy wo khud ba khud execute ho jaye us ko explicitly call krny ki need nhi hy.
    def __init__(self):
        self.pin = ''
        self.balance = 0
        self.menu()
    
    def menu(self):
        user_input = input("""
              Hi how can I help you?
              1. Press 1 to create pin.
              2. Press 2 to change pin.
              3. Press 3 to check balance.
              4. Press 4 to withdraw.
              5. Exit
        """)

        if user_input == '1':
            self.create_pin()
        elif user_input == '2':
            self.change_pin()
        elif user_input == '3':
            self.check_balance()
        elif user_input == '4':
            self.withdraw()
        else:
            exit()
        
    def create_pin(self):
        user_pin = input('enter your pin')
        self.pin = user_pin

        user_balance = int(input('enter balance'))
        self.balance = user_balance

        print('pin created successfully')
        self.menu()

    def change_pin(self):
        old_pin = input('enter old pin')

        if old_pin == self.pin:
            # let him change the pin
            new_pin = input('enter new pin')
            self.pin = new_pin
            print('pin change successful')
            self.menu()
        else:
            print('nai karne de sakta re baba')
            self.menu()

    def check_balance(self):
        user_pin = input('enter your pin')
        if user_pin == self.pin:
            print('your balance is ',self.balance)
        else:
            print('chal nikal yahan se')

    def withdraw(self):
        user_pin = input('enter the pin')
        if user_pin == self.pin:
            # allow to withdraw
            amount = int(input('enter the amount'))
            if amount <= self.balance:
                self.balance = self.balance - amount
                print('withdrawl successful.balance is',self.balance)
            else:
                print('abe garib')
        else:
            print('sale chor')
        self.menu()

# %%
obj = Atm()

# %%
obj2 = Atm()

# %%
class Atm:

  # constructor(special function)->superpower -> 
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.balance = 0
    #self.menu()

  def menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.balance = user_balance

    print('pin created successfully')
    self.menu()

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
      self.menu()
    else:
      print('nai karne de sakta re baba')
      self.menu()

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.balance:
        self.balance = self.balance - amount
        print('withdrawl successful.balance is',self.balance)
      else:
        print('abe garib')
    else:
      print('sale chor')
    self.menu()

# %%
obj1 = Atm()
# Out:
# 2504010318912

# %% [markdown]
# ## **Functions vs Methods**
#
# Class k andar ap jo function bnaty hy usy hum function nhi kehty.
#
# usy hum Methid bulaty hy
#
# or class k bahir jo function unko function bulaty hy.
#
# ### **Method:** **agr koi fuction class k ander hy to me usy Method bulao ga**
#
# ### **Function:** **or agr koi function independently exist krta hy outside of the class to usy function bulao ga**

# %% [markdown]
# Abhi aik swal hy mera ap sy

# %%
a = [7,3,32]

len(a) #Function--> bcz it is outside the class

a.append(0) #Method --> bcz it is inside the class

# %% [markdown]
# ### **Class Diagram**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## **Megic Method / Dunder Method**
#
# **Megic** is a special kind of method has a superpower.
# megic method ku6 aisa dikhta hy `__name__`
#
# hum already aik megec method dekh chuky hy constructor `__init__` me ny ap ko btaya tha k it has a super power k is k ander jo
#
# code hota hy usy alag sy call krny ki zroorat nhi hoti wo khud hi trigger ho jat hy jaise hi oject bnta hy
